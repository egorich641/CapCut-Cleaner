# %% [markdown]
# <a href="https://colab.research.google.com/github/egorich641/CapCut-Cleaner/blob/main/WebScrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nuhmanpk/WebScrapper.git
# Out:
# Cloning into 'WebScrapper'...
# remote: Enumerating objects: 340, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 340 (delta 27), reused 6 (delta 6), pack-reused 289 (from 3)
# Receiving objects: 100% (340/340), 540.97 KiB | 2.83 MiB/s, done.
# Resolving deltas: 100% (169/169), done.

# %%
# !pip install -r /content/WebScrapper/requirements.txt -qU
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 477.6/477.6 kB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.5 MB/s eta 0:00:00
# ...

# %%
BOT_TOKEN = 'TOKEN'
API_ID = 'API_ID'
API_HASH = 'API_HASH'
CRAWL_LOG_CHANNEL = '' # Channel ID where the Data to be sent

# %%
with open('.env', 'w') as f:
    f.write(f"BOT_TOKEN={BOT_TOKEN}\n")
    f.write(f"API_ID={API_ID}\n")
    f.write(f"API_HASH={API_HASH}\n")
    f.write(f"CRAWL_LOG_CHANNEL={CRAWL_LOG_CHANNEL}\n")

# %%
# !python3 /content/WebScrapper/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/WebScrapper/main.py", line 46, in <module>
#     "WebScrapperBot", bot_token=bot_token, api_id=int(api_id), api_hash=api_hash
#                                                   ^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'API_ID'
